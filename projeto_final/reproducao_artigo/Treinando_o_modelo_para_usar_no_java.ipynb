# %%
import pandas as pd

# Carregar os dados
from google.colab import files
uploaded = files.upload()

# Carregar o CSV para o DataFrame
df = pd.read_csv('diabetes_data_upload.csv')

# Exibir as primeiras linhas para inspecionar os dados
df.head()
# Out:
#      <input type="file" id="files-a81374ca-a625-49eb-af2b-e171ed5d258a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a81374ca-a625-49eb-af2b-e171ed5d258a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Exibindo as colunas do DataFrame para verificar o nome correto da coluna
df.columns
# Out:
# Index(['Age', 'Gender', 'Polyuria', 'Polydipsia', 'sudden weight loss',
#        'weakness', 'Polyphagia', 'Genital thrush', 'visual blurring',
#        'Itching', 'Irritability', 'delayed healing', 'partial paresis',
#        'muscle stiffness', 'Alopecia', 'Obesity', 'class'],
#       dtype='object')

# %%
# Separando as variáveis independentes (X) e dependentes (y)
X = df.drop('class', axis=1)  # Remover a coluna 'class' para usar como variável dependente
y = df['class']  # A coluna 'class' é a variável dependente

# %%
# Convertendo valores 'Yes'/'No' para 1/0 em todas as colunas
df = df.replace({'Yes': 1, 'No': 0})

# Convertendo a coluna 'Gender' para 1/0 ('Male' para 1 e 'Female' para 0)
df['Gender'] = df['Gender'].replace({'Male': 1, 'Female': 0})

# Separando as variáveis independentes (X) e a variável dependente (y)
X = df.drop('class', axis=1)
y = df['class']

# Dividindo os dados em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=50)

# Inicializando o modelo RandomForestClassifier
rf_model = RandomForestClassifier(criterion='gini', n_estimators=100, random_state=42)

# Treinando o modelo
rf_model.fit(X_train, y_train)

# Salvando o modelo treinado
import joblib
joblib.dump(rf_model, 'diabetes_rf_model.pkl')
# Out:
# <ipython-input-9-fddebdc551d9>:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Gender'] = df['Gender'].replace({'Male': 1, 'Female': 0})
# ['diabetes_rf_model.pkl']

# %% [markdown]
# Ate aqui o modelo foi treinado e gerado o arquivo pkl, para usar no java

# %%
# Carregar o modelo salvo
import joblib

# Carregar o modelo treinado
rf_model = joblib.load('diabetes_rf_model.pkl')

# Fazer previsões usando os dados de teste
predictions = rf_model.predict(X_test)

# Exibir as previsões
print(predictions)

# Avaliar a acurácia do modelo
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, predictions)
print(f"Acurácia do modelo: {accuracy:.2f}")
# Out:
# ['Positive' 'Negative' 'Negative' 'Negative' 'Positive' 'Negative'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Negative' 'Negative'
#  'Negative' 'Positive' 'Negative' 'Negative' 'Positive' 'Negative'
#  'Positive' 'Positive' 'Positive' 'Negative' 'Positive' 'Negative'
#  'Positive' 'Negative' 'Negative' 'Negative' 'Positive' 'Negative'
#  'Negative' 'Positive' 'Negative' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Negative' 'Positive' 'Positive' 'Negative' 'Positive'
#  'Negative' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Negative' 'Negative' 'Positive' 'Positive' 'Positive' 'Negative'
#  'Positive' 'Negative' 'Negative' 'Negative' 'Positive' 'Negative'
#  'Negative' 'Negative' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Negative' 'Positive' 'Negative' 'Negative' 'Positive' 'Negative'
#  'Negative' 'Positive' 'Positive' 'Positive' 'Positive' 'Negative'
# ...

# %%
# Importar as bibliotecas necessárias
import joblib
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report

# Carregar o modelo salvo
rf_model = joblib.load('diabetes_rf_model.pkl')

# Fazer previsões usando os dados de teste
predictions = rf_model.predict(X_test)

# Exibir a acurácia do modelo
accuracy = accuracy_score(y_test, predictions)
print(f"Acurácia do modelo: {accuracy:.2f}")

# Exibir o relatório de classificação
print("\nRelatório de Classificação:")
print(classification_report(y_test, predictions))

# Criar um DataFrame com os dados de teste, as previsões e as classes reais
results_df = X_test.copy()  # Copia os dados de teste para o DataFrame de resultados
results_df['Real'] = y_test.values  # Adiciona a coluna com as classes reais
results_df['Predição'] = predictions  # Adiciona a coluna com as previsões do modelo

# Exibir as primeiras linhas do DataFrame com os resultados
print("\nExemplo de Resultados:")
print(results_df.head(10))  # Mostra as 10 primeiras previsões
# Out:
# Acurácia do modelo: 0.95
#
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#     Negative       0.95      0.93      0.94        58
#     Positive       0.95      0.96      0.95        72
#
#     accuracy                           0.95       130
#    macro avg       0.95      0.94      0.95       130
# weighted avg       0.95      0.95      0.95       130
#
#
# Exemplo de Resultados:
#      Age  Gender  Polyuria  Polydipsia  sudden weight loss  weakness  \
# 23    48       1         0           1                   1         1
# 399   64       1         0           0                   0         1
# 393   51       0         0           0                   0         0
# 236   60       1         0           0                   0         1
# 102   90       0         0           1                   1         0
# 370   45       1         0           0                   0         0
# 451   60       0         1           1                   1         1
# ...

# %%
# !pip install sklearn2pmml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 56.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 7.6 MB/s eta 0:00:00
# ...
#   Created wheel for sklearn2pmml: filename=sklearn2pmml-0.111.1-py3-none-any.whl size=7238294 sha256=2c0a1d8ac238c77d80a8b97a2ddbdcc13c15f27fc4731ac46f72e443190132ca
#   Stored in directory: /root/.cache/pip/wheels/10/04/64/0638bdddf705071688cab5b51f9c843f570f38dfb53f0d19d3
# Successfully built sklearn2pmml
# ...

# %%
from sklearn2pmml import PMMLPipeline, sklearn2pmml
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import joblib

# Carregar o modelo e os dados
model = joblib.load("diabetes_rf_model.pkl")
pipeline = PMMLPipeline([("classifier", model)])

# Salvar o modelo em formato PMML
sklearn2pmml(pipeline, "diabetes_rf_model.pmml")

# %%
# !ls /content
# Out:
# diabetes_data_upload.csv  diabetes_rf_model.pkl  diabetes_rf_model.pmml  sample_data

# %%
from google.colab import files
files.download("/content/diabetes_rf_model.pmml")

# %%
from google.colab import files
files.download("/content/diabetes_rf_model.pkl")

# %%
import pandas as pd

data = {
    'Age': [50],
    'Gender': [1],  # 1 para masculino, 0 para feminino, por exemplo
    'Polyuria': [0],  # 0 para "No", 1 para "Yes"
    'Polydipsia': [0],
    'sudden weight loss': [0],
    'weakness': [0],
    'Polyphagia': [0],
    'Genital thrush': [0],
    'visual blurring': [0],
    'Itching': [0],
    'Irritability': [0],
    'delayed healing': [0],
    'partial paresis': [0],
    'muscle stiffness': [0],
    'Alopecia': [0],
    'Obesity': [0]
}

# Criar DataFrame com os dados
input_data = pd.DataFrame(data)

# Fazer a previsão
prediction = model.predict(input_data)

# Exibir o resultado
print(f"Predição: {prediction}")
# Out:
# Predição: ['Negative']

# %%
import pandas as pd

data = {
    'Age': [50],
    'Gender': [1],  # 1 para masculino, 0 para feminino
    'Polyuria': [1],  # 1 para "Yes" (Síndrome de Poliúria)
    'Polydipsia': [1],  # 1 para "Yes" (Síndrome de Polidipsia)
    'sudden weight loss': [1],  # 1 para "Yes" (Perda de peso súbita)
    'weakness': [1],  # 1 para "Yes" (Fraqueza)
    'Polyphagia': [1],  # 1 para "Yes" (Polifagia)
    'Genital thrush': [1],  # 1 para "Yes" (Candidíase genital)
    'visual blurring': [1],  # 1 para "Yes" (Visão embaçada)
    'Itching': [1],  # 1 para "Yes" (Coceira)
    'Irritability': [1],  # 1 para "Yes" (Irritabilidade)
    'delayed healing': [1],  # 1 para "Yes" (Cicatrização lenta)
    'partial paresis': [1],  # 1 para "Yes" (Paralisia parcial)
    'muscle stiffness': [1],  # 1 para "Yes" (Rigidez muscular)
    'Alopecia': [1],  # 1 para "Yes" (Alopecia)
    'Obesity': [1]  # 1 para "Yes" (Obesidade)
}

# Criar DataFrame com os dados
input_data = pd.DataFrame(data)

# Fazer a previsão
prediction = model.predict(input_data)

# Exibir o resultado
print(f"Predição para uma linha ajustada para positivo: {prediction}")
# Out:
# Predição para uma linha ajustada para positivo: ['Positive']
