# %%
# Separar o backend interativo
#%matplotlib notebook

# Usa o backend inline, específico para Colab
# %matplotlib inline

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d  # gráficos 3D

# Cria a figura
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Gera dados de teste
X, Y, Z = axes3d.get_test_data(0.1)

# Plota o wireframe
ax.plot_wireframe(X, Y, Z)

# Exibe o gráfico interativo
plt.show()

# salva figura em arquivo
#plt.savefig('figura3d.png')
# Out:
# <div id='966e96be-d5ee-4375-9ab0-16e44c8b7f95'></div>
# <div id='9e2c85ec-e292-4dd8-a78b-5385381e3b28'></div>
# <div id='9a76e993-6e88-40d6-95bd-651e19c3bd27'></div>
